# %%
#W3A1
n=int(input("nhập số: "))
a=str(n)
b=a[::-1]
c=int(b)
print(c)
# Out:
# 4321

# %%
#W3A2
a,b=map(int,input("nhập 2 số: ").split())
b=a^b
a=a^b
b=a^b
print(f"sau khi hoán đổi: {a},{b}")
# Out:
# sau khi hoán đổi: 2,1

# %%
#W3A3
n=int(input("nhập số: "))
if n>0 and (n&(n-1))==0:
    print(f"{n} là số nguyên dương và là lũy thừa của 2")
else:
    print(f"{n} không phải là số nguyên dương hoặc không phải là lũy thừa của 2")
# Out:
# 8 là số nguyên dương và là lũy thừa của 2

# %%
#W3A4
import math
m,n=map(int,input("nhập 2 số: ").split())   
c=math.floor(m/n)
print(c)
# Out:
# 1

# %%
#W3A5
import math
m,n=map(int,input("nhập 2 số: ").split())
c=math.ceil(m/n)
print(c)
# Out:
# 2

# %%
#W3A6
n=int(input("nhập số nguyên dương: "))
if n%2==0:
    print("Even")
else:
    print("Odd")

# %%
#W3A7
a,b=map(int,input("nhập 2 số: ").split())
if a<0 and b<0:
    print("Yes")
else:
    print("No")

# %%
#W3A8
a=input()
b=input()
if len(a)>len(b):
    print("Yes")
else:
    print("No")

# %%
#W3A9
a,b,c=map(int,input("nhập 3 nguyên : ").split())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3A10
a,b,c,d=map(int,input("nhập 4 nguyên : ").split())
e=max(a,b,c,d)
print(e)

# %%
#w3a11
a,b,c=map(int,input("nhập 3 nguyên : ").split())
if a+b>c and a+c>b and b+c>a:
    if a == b == c :
        print("tam giác đều ")
    elif a == b or a == c or b == c:
        print("tam giác cân")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print("tam giác vuông")
    else:
        print("tam giác thường")
else:
    print("không phải là tam giác")
# Out:
# tam giác vuông

# %%
#w3a12
a=int(input("nhập năm : "))
if (a%4==0 and a%100!=0) or (a%400==0):
    print(f"{a} là năm nhuận")
else:
    print(f"{a} không phải là năm nhuận")
# Out:
# 2001 không phải là năm nhuận

# %%
#w3a13
a=int(input("nhập số điện tiêu thụ: "))
if a<=50:
    bill=a*1500
    print(f"hóa đơn điện của bạn là: {bill}")
elif a<=100 and a>50:
    bill=50*1500+(a-50)*2000
    print(f"hóa đơn điện của bạn là: {bill}")
elif a>100:
    bill=50*1500+50*2000+(a-100)*2500
    print(f"hóa đơn điện của bạn là: {bill}")
# Out:
# hóa đơn điện của bạn là: 75000

# %%
#w3a14
a,b=map(int,input("nhập 2 hệ số: ").split())
if a==0 and b==0:
    print("phương trình vô số nghiệm")
elif a==0 and b!=0:
    print("phương trình vô nghiệm")
elif a!=0:
    x=-b/a
    print(f"phương trình có nghiệm x={x}")
# Out:
# phương trình có nghiệm x=-2.0

# %%
#w3a15
c=int(input("nhập điểm trung bình: "))
if c>=8:
    print("Giỏi")
elif c>=6.5 and c<8:
    print("Khá")        
elif c>=5 and c<6.5:
     print("Trung bình")
elif c<5:
    print("Yếu")

# %%
#w3a16
a=float(input("nhập số thực: "))
b=abs(a-int(a))
if a>0:
    if b>=0.5:
        print(f"{a} được làm tròn lên {int(a)+1}")
        print(f"{a} làm tròn đến số nguyên gần nhất {int(a)+1}")
    else:
        print(f"{a} được làm tròn xuống {int(a)}")
        print(f"{a} làm tròn đến số nguyên gần nhất {int(a)}")
elif a<0:
    if b<=0.5:
        print(f"{a} được làm tròn lên {int(a)}")
        print(f"{a} làm tròn đến số nguyên gần nhất {int(a)}")
    else:
        print(f"{a} được làm tròn xuống {int(a)-1}")
        print(f"{a} làm tròn đến số nguyên gần nhất {int(a)-1}")
# Out:
# -7.6 được làm tròn xuống -8
# -7.6 làm tròn đến số nguyên gần nhất -8

# %%
#w3a17
a,b,c,d=map(int,input("nhập 4 số: ").split()) 
if  (b/a)==(c/b)==(d/c):    
    print("Yes")
else:    
    print("No")
# Out:
# No
