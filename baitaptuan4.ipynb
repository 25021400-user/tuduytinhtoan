# %%
#w4a1
n=int(input("nhap so nguyen n<= 1000"))
tong = 0
for i in range(1,n+1):
    tong = tong +i
print(f"tong tu 1 den n :{tong}")
# Out:
# tong tu 1 den n :6

# %%
#w4a2
i=-1
while i<0:
    a=int(input("nhap so nguyen n:"))
    if a >0:
        break
if a>1:
    for b in range(2,a):
        if a%b==0:
            break
    else:
        print(f" so {a} co la so nguyen to")
# Out:
#  so {a} co la so nguyen to

# %%
#w4a3
n=int(input("nhap so nguye n:"))
giaithua=1
for i in range(1,n+1):
    giaithua=giaithua*i
print(f"giai thua cua {n} la: {giaithua}")
# Out:
# giai thua cua 6 la: 720

# %%
#w4a4
n=int(input("nhập số nguyên dương: "))
so=0

for i in range(n+1):
    a=(n//(10**i))%10
    so=so+1
    if a==0 and n//(10**i)==0:
        so=so-1
        break
print(f"Số {n} có {so} chữ số")
# Out:
# Số 12 có 2 chữ số

# %%
#w4a5
n=int(input("nhap so nguyen dương:"))
day=list(map(int,input().split()))
for i in range(n):
    if day[i]==42:
        break
if day[i]==42:
    print("I've found the meaning of life")
else:
    print("It's a joke")
# Out:
# I've found the meaning of life

# %%
#w4a6
i=-1
while i<0:
    a,b =map(int,input().split())
    if a<=b:
        break
tong=0
for c in range(a,b+1):
    if c>1:
        for d in range(2,c):
            if c%d==0:
                break
        else:
            tong= tong+c
print(f"tong cac so nguen to trong doan [{a},{b}]:{tong}")
# Out:
# tong cac so nguen to trong doan [1,2]:2

# %%
#w4a7
i=-1
while i<0:
    n=int(input("nhap so nguyen n(n>=2):"))
    if n>=2:
        break
max=0
for x in range(2,n+1):
    if n%x==0:
        for a in range(2,x):
            if x%a==0:
                break
        else:
            if max <= x:
                max=x   
print(f"uoc nguyen to lon nhat cua {n} la:{max}")
# Out:
# uoc nguyen to lon nhat cua 97 la:97

# %%
#w4a8
n=int(input('nhap so nguyen n:'))
i=-1
a=n
while i<0:
    a=a+int(str(n)[::-1])
    if str(a)==str(a)[::-1]:
        break
print(f" gia tri palindrome nha duoc khi cong {n} voi reverse({n}) la:{a}")
# Out:
#  gia tri palindrome nha duoc khi cong 123 voi reverse(123) la:444

# %%
#w4a9
n=int(input("nhap so nguyen duong:"))
a=0
for x in range(1,n):
    for y in range(1,x):
        if y**2==x:
            a=1
            break
    if a==1:
        b=str(n)
        for c in range(len(b)):
            for d in range(c+1,len(b)):
                if b[c]==b[d]:
                    break
                else:
                    a=2
        if a==2:
            print(x, end=" ")
# Out:
# 4 9 16 25 36

# %%
#w4a10
n=int(input("nhap so nguyen duowng n:"))
maxlen=0
res=1
for x in range(1,n+1):
    a=x
    dodaiday=1
    while a!=1:
        if a%2==0:
            a=a//2
        else:
            a=a*3+1
        dodaiday=dodaiday+1
    if maxlen<dodaiday:
        maxlen=dodaiday
        res=x
    elif maxlen==dodaiday:
        if res>x:
            res=x
print(f"so co do dai day collatz lon nhat la {res},do dai la {maxlen}")
# Out:
# so co do dai day collatz lon nhat la 97,do dai la 119

# %%
#w4a11
i=-1
souocchan=0
while i<0:
    n=int(input("nhap so nguyen duong n:"))
    if n< 10**6:
        break
for i in range(1,n+1):
    if n%i==0 and i%2==0:
        souocchan=souocchan+1
print(f"so uoc chan cua {n} la {souocchan}")
# Out:
# so uoc chan cua 11 la 0

# %%
#w4a12(lai kep)
x=int(input("so tien gui:"))
n=int(input("so thang gui:"))
for i in range(1,n+1):
    x=x*(1+(0.7/100))
print(f"so tien rut duoc la: {x:.0f}")
# Out:
# so tien rut duoc la: 108731066

# %%
#w4a12(lai don)
x=int(input("so tien gui:"))
n=int(input("so thang gui:"))
tienlai=0
for i in range(1,n+1):
    tienlai += x*(0.7/100)
tongtienrut= x + tienlai
print(f"so tien rut duoc la: {tongtienrut:.0f}")
# Out:
# so tien rut duoc la: 108400000

# %%
#w4a13
a,b=map(int,input("nhap 2 so nguyen:").split())
tonguoca=0
tonguocb=0
for i in range(1,a):
    if a%i==0:
        tonguoca=tonguoca+i
for k in range(1,b):
    if b%k==0:
        tonguocb=tonguocb+k
if tonguoca==b and tonguocb==a:
   print(True)
else:
    print(False)
# Out:
# True

# %%
#w4a14
m,n= map(int,input("nhap 2 so nguyen duong:").split())
uocchung=0
for a in range(1,m+1):
    if m%a==0:
        for b in range(1,n+1):
            if n%b==0:
                if a==b:
                   c=a
    if uocchung<c:
        uocchung=c
print(f"uoc chung lon nhat cua {m} va {n} la:{uocchung}")
# Out:
# uoc chung lon nhat cua 99 va 81 la:9

# %%
#w4a15
a=int(input("nhap tong so con:"))
b=int(input("tong so chan ga va cho:"))
x=a-(b-2*a)/2
y=(b-2*a)/2
if x==int(x) and y==int(y):
   print(f"so luong con ga la:{x},so luong con ga la:{y} ")
else:
   print("invalid")
# Out:
# invalid
