# %%
#W6A1
lst=list(map(int,input().split()))
lst1=[]
for i in lst:
    if i not in lst1:
        lst1.append(i)
print(lst1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#W6A2
n=list(map(int,input().split()))
a=[]
tong=0
for i in n:
    tong=tong+i
    a.append(tong)
print(a)
# Out:
# [1]

# %%
#w6a3
a=list(map(int,input().split()))
b=tuple(a)
k=int(input())
if k < len(b):
    c=[]
    d=[]
    for i in range(k):
        c.append(a[i])
    for j in range(k,len(a)):
        d.append(a[j])
    e=tuple(d+c)
print(b)
print(f"k={k}")
print(e)
# Out:
# (1, 2, 3, 4, 5)
# k=3
# (4, 5, 1, 2, 3)

# %%
#w6a4
a=input().split()
b={}
for i in a:
    key, value=i.split(":")
    if key not in b:
        b[key] = [value] 
    else:
        b[key].append(value)
print(b)
# Out:
# {'a': ['1', '4'], 'b': ['2'], 'c': ['1']}

# %%
#w6a5
lst=list(map(int,input().split()))
a=0
b=0
c=0
for i in lst:
    if i >0:
        a=a+1
    if i<0:
        b=b+1
    if i==0:
        c=c+1
d=dict(positives=a,negatives=b,zeros=c)
print(d)
# Out:
# {'positives': 6, 'negatives': 0, 'zeros': 1}

# %%
#w6a6
lst=list(map(int,input().split()))
tong=0
for i in lst:
    tong+=i
print(tong)
# Out:
# 10

# %%
#w6a7
a=tuple(map(int,input().split()))
print(a[0])
print(a[-1])
print(a[::-1])
# Out:
# 1
# 9
# (9, 8, 7, 6, 5, 4, 3, 2, 1)

# %%
#w6a8
lst=list(input().split())
dic={}
for i in lst:
    tong=0
    for j in lst:
        if j==i:
            tong+=1
            dic[i]=tong
print(dic)
# Out:
# {'apple': 1, 'banana': 1}

# %%
#w6a9
a=input().split()
b=input().split()
dic1={}
dic2={}
for i in a:
    key, value=i.split(":")
    dic1[key]=value
for i in b:
    key, value=i.split(":")
    dic2[key]=value
dic3={}
for i in dic1:
    if i in dic2:
        value=int(dic1[i])+int(dic2[i])
        dic3[i]=str(value)
    if i not in dic2:
        dic3[i]=dic1[i]
for i in dic2:
    if i not in dic1:
        dic3[i]=dic2[i]
print(dic1)
print(dic2)
print(dic3)
# Out:
# {'a': '1'}
# {'a': '2'}
# {'a': '3'}

# %%
#w6a10
lst=(input().split()) #moi cap so cos dang a:b
k=int(input())
lst1=[]
for i in lst:
    a,b=i.split(":")
    c=(int(a),int(b))
    lst1.append(c)
lst2=[]
for i in lst1:
    if i[0]+i[1]==k:
        lst2.append(i)
lst2 = list(dict.fromkeys(lst2))
lst2.sort(key=lambda x: x[0])
print(lst2)
# Out:
# [(3, 4), (4, 3)]

# %%
#w6a11
a=tuple(map(int,input().split()))
b=()
c=()
for i in a:
    if i%2==0:
       b=b+(i,)
    else:
       c=c+(i,)
print(a)
print(b)
print(c)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 5, 8)
# (2, 4, 6, 8)
# (1, 3, 5, 7, 5)

# %%
#w6a12
lst=list(map(int,input().split()))
a=max(lst)
sl=0
for i in lst:
    tong=0
    for j in lst:
        if i==j:
            tong=tong+1
    if tong>sl:
        sl=tong
    if i<a:
        a=i
print(lst)
print(f"so nhieu nhat trong list la:{a} voi so lam la:{tong}")
# Out:
# [1, 2, 3, 4, 5, 2, 3, 1, 1, 2, 1, 1, 1]
# so nhieu nhat trong list la:1 voi so lam la:6

# %%
#w6a13
a=input().split()
dic1={}
for i in a:
    key, value=i.split(":")
    dic1[key]=value
dic2={}
for i in dic1:
    a=(dic1[i])
    dic2[a]=(i)
print(dic1)
print(dic2)
# Out:
# {'1a': '1', 'b': '2', 'c': '3'}
# {'1': '1a', '2': 'b', '3': 'c'}

# %%
#w6a14
a=list(map(int,input().split()))
b=list(map(int,input().split()))
c=[]
for i in a:
    if i in b and i not in c:
        c.append(i)

print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 7, 6, 5, 4, 3, 0]
# [3, 4, 5, 6, 7, 8, 9]

# %%
#w6a15
a=input("nhap key la chuoi value la so nguyen").split()
k=int(input())
dic1={}
dic2={}
for i in a:
    b,c=i.split(":")
    dic1[b]=c
    if int(c)>k:
        dic2[b]=c
print(dic1)
print(f"k={k}")
print(dic2)
# Out:
# {'a': '10', 'b': '20', 'c': '30'}
# k=100
# {}
