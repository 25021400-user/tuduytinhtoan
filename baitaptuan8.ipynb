# %%
#w7a16
n = list(map(int, input().split()))
print(n)
a=[]
for i in n:
    if i not in a:
        a.append(i)
for i in a:
    solan=n.count(i)
    if solan == i:
        b=True
    else:        
        b=False

        break
if b:    
    print("co la mang dep")
else:
    print("khong la mang dep")
    c=[]
    for i in a:
        solan=n.count(i)
        if solan==i:
            for j in range(i):
                c.append(i)
        if solan!=i:
            if solan>i:
                for j in range(i):
                    c.append(i)
            else:
                continue
    print(c)
# Out:
# [1, 2, 2, 3, 3, 3]
# co la mang dep

# %%
#w7a17
a=list(map(int, input().split()))
n=len(a)
phantu= None
solan=0
print(a)
for i in a:
    if solan==0:
        phantu=i
        solan=1
    elif i==phantu:
        solan+=1
    else:
        solan-=1
check=0
for i in a:
    if i==phantu:
        check+=1
if check>n//2:
    print(phantu)
else:
    print("Khong co phan tu phu hop")
# Out:
# [1, 2, 2, 3, 2, 2]
# 2

# %%
#w7a18
a=list(map(int,input().split()))
chan=[]
le=[]
for i in a:
    if i%2==0:
        chan.append(i)
    else:
        le.append(i)
def meg(arr,st,mid,en):
    i=st
    j=mid
    tmp=[]
    while i<mid and j<en:
        if arr[i]<arr[j]:
            tmp.append(arr[i])
            i+=1
        else:
            tmp.append(arr[j])
            j+=1
    while i<mid:
        tmp.append(arr[i])
        i+=1
    while j<en:
        tmp.append(arr[j])
        j+=1
    for i in range(len(tmp)):
        arr[i+st]=tmp[i] 

def meg_sort(arr,st,en):
    if (en-st)<=1:
        return
    mid=(en+st)//2
    meg_sort(arr,st,mid)
    meg_sort(arr,mid,en)
    meg(arr,st,mid,en)
meg_sort(chan,0,len(chan))
meg_sort(le,0,len(le))
le=le[::-1]
print(a)
print(chan+le)
# Out:
# [1]
# [1]

# %%
#w7a19
a=list(map(int, input("nhập vào mẩng đã sắp xếp tăng hoạc giảm: ").split()))
b=list(map(int, input("nhập vào mẩng đã sắp xếp tăng hoạc giảm: ").split()))
if a[0]>a[-1]:
    a=a[::-1]
if b[0]>b[-1]:
    b=b[::-1]
i,j=0,0
c=[]
while i<len(a) and j<len(b):
    if a[i]<b[j]:
        c.append(a[i])
        i+=1
    else:
        c.append(b[j])
        j+=1
c.extend(a[i:])
c.extend(b[j:])
print(a)
print(b)
print(c)
# Out:
# [1]
# [1]
# [1, 1]

# %%
#w7a20
n=list(map(int, input().split()))
k=int(input("nhập vào k: "))
tong=0
for i in n:
    a=len(str(i))
    if a==k:
        tong+=i
print(n)
print(k)
print(tong)
# Out:
# [12, 3, 123, 34, 5, 6, 7]
# 2
# 46

# %%
#w7a21
N=int(input("nhập ngày: "))
T=int(input("nhập tháng: "))
nam=2020

def check(N,T):
    maxday=0
    match T:
        case 1|3|5|7|8|10|12:
             maxday=31
        case 4|6|9|11:
             maxday=30
        case 2:
             maxday=29
    if N>0 and N<=maxday:
        return True
    else:        return False
if check(N,T):
    print("ngay hop le")
    tongngay=0
    for i in range(1,T):
        match i:
            case 1|3|5|7|8|10|12:
                 tongngay+=31
            case 4|6|9|11:
                 tongngay+=30
            case 2:
                 tongngay+=29
    tongngay+=N
    print(f"ngày{N}tháng{T}năm{nam} là ngày thứ {tongngay} trong năm")
else:   
    print("ngày không hợp lệ")
# Out:
# ngay hop le
# ngày2tháng1năm2020 là ngày thứ 2 trong năm

# %%
#w7a22
n = int(input("Nhập số lượng sinh viên: "))
danh_sach = []
dem = {}

for _ in range(n):
    ho_ten = input("Nhập họ và tên: ")
    ten = ho_ten.split()[-1]
    danh_sach.append(ho_ten)

    if ten in dem:
        dem[ten] += 1
    else:
        dem[ten] = 1

ten_hay_gap = None
max_count = 0

for ten, count in dem.items():
    if count > max_count:
        max_count = count
        ten_hay_gap = ten
    elif count == max_count:
        if ten < ten_hay_gap:
            ten_hay_gap = ten
print(f"Tên hay gặp nhất là '{ten_hay_gap}' với {max_count} lần xuất hiện.")
# Out:
# Tên hay gặp nhất là 'binh' với 1 lần xuất hiện.

# %%
#w7a23
a=input("nhập 1 sâu bất kì:")
print(a)
for i in a:
    if not i.isalpha():
        a=a.replace(i," ")
b=a.split()
soten=0
for i in b:
    if len(b)>=2 and i.istitle():
        soten+=1
        print(i)
print( soten)
# Out:
# ban ay ten Linh, ban di canh ten Hieu,  voi may nguoi ban moi ten khong biet
# Linh
# Hieu
# 2

# %%
#w7a24
a=input().split()
d=[]
for i in a:
    if i not in d:
        d.append(i)
b=""
for i in d:
    b=b+str(i)+" "
print(b)
# Out:
# Toi di hoc, rat vui khi hoc voi cac ban.

# %%
#w7a25
a=input()
k=int(input())
c=[]
for i in a:
    if i.isdigit():
        c.append(int(i))

stack=[]
solanxoa=len(c)-k
for i in c:
    if len(stack)==0:
        stack.append(i)
        continue
    if i > stack[-1]:
        solan=0
        for j in reversed(stack):
            if j<i and solan<solanxoa:
                solan+=1
            else:
                break
    
        for j in range(solan):
            stack.pop()
        stack.append(i)
        solanxoa-=solan  
        continue     
    if i<=stack[-1]:
        stack.append(i)
        continue
    if solanxoa==0:
        break
if solanxoa>0:
    stack=stack[:-solanxoa]

b=''
for i in stack:
    b+=str(i)
print(int(b))
# Out:
# 8978676767

# %%
#w7a26
a=input()
b=""
solan=0
tong=0
for i in a:
    if  i.isdigit():
        b+=i

    else:
       b+=" "
      
c=b.split()
for i in c :
    tong+=int(i)
    solan+=1
if solan==0:
    print("không có số trong chuỗi")
else:
    tbc=tong/solan
    print(a)
    print(tong)
    print(tbc)
# Out:
# 12rere90dsfdsf0sere234
# 336
# 84.0

# %%
#w7a27
a = input("Nhập 1 dãy ngoặc: ")
ds = []
hop_le = True  
for i in a:
    if i in "({[":
        ds.append(i)
    elif i in ")}]":
        if not ds:
            hop_le = False
            break
        b = ds.pop() 
        if (i == ')' and b != '(') or \
           (i == '}' and b != '{') or \
           (i == ']' and b != '['):
            hop_le = False
            break


if hop_le and len(ds) == 0:
    print("Dãy hợp lệ")
else:
    print("Dãy không hợp lệ")
# Out:
# Dãy hợp lệ

# %%
#w7a28
def songuyento(a):
    if a < 2: return False
    for i in range(2, int(a**0.5) + 1):
        if a % i == 0:
            return False  
    return True  
n = int(input("Nhập N: "))
a=[]
for i in range(2,n):
    a.append(i)
daylonnhat = []
daythu = []

for i in a:
    
    if i>1 and not songuyento(i):
        daythu.append(i)
    else:
        if len(daythu) > len(daylonnhat):
            daylonnhat = daythu.copy()
        daythu = [] 

if len(daythu) > len(daylonnhat):
    daylonnhat = daythu.copy()
print(a)
print("Dãy hợp số dài nhất là:", daylonnhat)

# %%
#w7a29
a = list(map(int, input("Nhập dãy số: ").split()))
daylonnhat = []
daythu = [a[0]]
for i in range(len(a)-1):

    if a[i]<a[i+1]:
        daythu.append(a[i+1])
    else:
        if len(daythu) > len(daylonnhat):
            daylonnhat = daythu.copy()
            daythu = [a[i+1]] 
if len(daythu) > len(daylonnhat):
    daylonnhat = daythu.copy()
print(a)
print("Dãy số dài nhất là:", daylonnhat)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 9, 10, 12]
# Dãy số dài nhất là: [1, 2, 3, 4, 9, 10, 12]

# %%
#w7a30
a = list(map(int, input("Nhập dãy số: ").split()))

if not a:
    print("Dãy rỗng")
else:
    n = len(a)
    L = [1] * n
    for i in range(1, n):
        for j in range(0, i):
            if a[j] <= a[i]:
                L[i] = max(L[i], L[j] + 1)
    max_len = max(L)
    print("Độ dài của dãy con tăng dần dài nhất là:", max_len)
    lis = []
    current_len = max_len
    for i in range(n - 1, -1, -1):
        if L[i] == current_len:
            lis.append(a[i])
            current_len -= 1
    lis.reverse()
    print("Dãy con tăng dần dài nhất đó là:", lis)
# Out:
# Độ dài của dãy con tăng dần dài nhất là: 11
# Dãy con tăng dần dài nhất đó là: [1, 2, 3, 4, 5, 6, 6, 7, 9, 10, 12]

# %%
#w7a31
a=int(input())
c=[]
for i in str(a):
        c.append(int(i))
print(a)
sonhonhat=int(a)
for i in range(len(c)):
    for j in range(i+1,len(c)):
        d=c.copy()
        d[i],d[j]=d[j],d[i]
        b=''
        for k in d:
            b+=str(k)
        e=int(b)
        if e<sonhonhat:
            sonhonhat=e
print(sonhonhat)
# Out:
# 1000000000002343454000001213
# 2343454000011213
